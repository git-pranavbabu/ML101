# %% [markdown]
# <a href="https://colab.research.google.com/github/git-pranavbabu/ML101/blob/master/RandomForest/randomForest_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

from io import StringIO

# %%
data = '''Age,Department,YearsAtCompany,PerformanceScore,AvgTrainingScore,Promoted
25,Sales,1,3,60,0
28,Sales,3,4,70,1
35,HR,7,5,85,1
40,HR,10,4,78,1
30,Sales,5,3,65,0
45,Management,15,5,90,1
26,Sales,2,2,55,0
38,HR,9,4,80,1
29,Sales,4,3,68,0
34,Sales,6,4,75,1
41,Management,12,5,88,1
27,Sales,2,2,58,0
36,HR,8,4,82,1
31,Sales,5,3,72,0
39,Management,11,5,86,1'''

# %%
df = pd.read_csv(StringIO(data))
df
# Out:
#     Age  Department  YearsAtCompany  PerformanceScore  AvgTrainingScore  \
# 0    25       Sales               1                 3                60
# 1    28       Sales               3                 4                70
# 2    35          HR               7                 5                85
# 3    40          HR              10                 4                78
# 4    30       Sales               5                 3                65
# 5    45  Management              15                 5                90
# 6    26       Sales               2                 2                55
# 7    38          HR               9                 4                80
# 8    29       Sales               4                 3                68
# 9    34       Sales               6                 4                75
# 10   41  Management              12                 5                88
# 11   27       Sales               2                 2                58
# ...

# %%
le = LabelEncoder()
df['Department'] = le.fit_transform(df['Department'])
df
# Out:
#     Age  Department  YearsAtCompany  PerformanceScore  AvgTrainingScore  \
# 0    25           2               1                 3                60
# 1    28           2               3                 4                70
# 2    35           0               7                 5                85
# 3    40           0              10                 4                78
# 4    30           2               5                 3                65
# 5    45           1              15                 5                90
# 6    26           2               2                 2                55
# 7    38           0               9                 4                80
# 8    29           2               4                 3                68
# 9    34           2               6                 4                75
# 10   41           1              12                 5                88
# 11   27           2               2                 2                58
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Promoted', axis=1), df['Promoted'], test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[2 0]
#  [0 1]]

# %%
#predicting using custom row
x_custom = pd.DataFrame({
    'Age': [30],
    'Department': [le.transform(['Sales'])[0]],
    'YearsAtCompany': [10],
    'PerformanceScore': [5],
    'AvgTrainingScore': [50]
})
print(model.predict(x_custom))
# Out:
# [1]
